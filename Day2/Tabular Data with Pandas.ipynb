# %% [markdown]
# <h1><center>Python For Machine Learning: A Beginner's Workshop</center></h1>

# %% [markdown]
# <h2><center>Chapter 2</center></h2>
# <h2><center>Playing with tabular Data: Pandas</center></h2>
# <h2><center>UE19EC353:  Machine Learning</center></h2>
# <h2><center>Jan - May 2022</center></h2>

# %% [markdown]
# ##### This Jupyter notebook is a part of the workshop held for introducing Python for Machine Learning. It is a part of the course UE19EC353:  Machine Learning for the Jan-May 2022 session for students of the 6th sem of the ECE Dept of PES University (RR and EC Campus)

# %% [markdown]
# ## What is Pandas?

# %% [markdown]
# ![pandas.jfif](attachment:pandas.jfif)

# %% [markdown]
# Nope. Although it looks cute, it is no way related to pandas!!

# %% [markdown]
# Pandas is a python library for data analysis. Pandas stands for "Python Data Analysis Library "Pandas is a fast, powerful, flexible and easy to use open source data analysis and manipulation tool, built on top of the Python programming language

# %% [markdown]
# ### 1.1 Installing pandas

# %% [markdown]
# $ pip install pandas

# %%
import pandas
import pandas as pd

# %% [markdown]
# ### 1.2 Pandas Data structures

# %% [markdown]
# #### 1.2.1 Pandas Series

# %% [markdown]
# Pandas series is a one dimensional labeled array capabale of holding any data type

# %%
s = pd.Series([1,2,3,4],index=['a','b','c','d'])

# %%
s
# Out:
# a    1
# b    2
# c    3
# d    4
# dtype: int64

# %% [markdown]
# #### 1.2.1 Pandas Dataframe

# %% [markdown]
# The dataframe represents a 2 dimensional labeled data structure with columns of potentially different types

# %%
## LOL. Data not accurate
data = {'Country': ['Belgium', 'India', 'Brazil'],
'Capital': ['Brussels', 'New Delhi', 'Brasília'],
'Population': [11190846, 1303171035, 207847528]}

# %%
data
# Out:
# {'Country': ['Belgium', 'India', 'Brazil'],
#  'Capital': ['Brussels', 'New Delhi', 'Brasília'],
#  'Population': [11190846, 1303171035, 207847528]}

# %%
df = pd.DataFrame(data,columns=['Country','Capital','Population'])

# %%
df
# Out:
#    Country    Capital  Population
# 0  Belgium   Brussels    11190846
# 1    India  New Delhi  1303171035
# 2   Brazil   Brasília   207847528

# %% [markdown]
# ### 2.3 Selecting with pandas

# %%
s
# Out:
# a    1
# b    2
# c    3
# d    4
# dtype: int64

# %%
s[1]
# Out:
# 2

# %%
s['b']
# Out:
# 2

# %%
df[1:]
# Out:
#   Country    Capital  Population
# 1   India  New Delhi  1303171035
# 2  Brazil   Brasília   207847528

# %%
df[1:3]
# Out:
#   Country    Capital  Population
# 1   India  New Delhi  1303171035
# 2  Brazil   Brasília   207847528

# %%
#Getting subset
df[1:2]
# Out:
#   Country    Capital  Population
# 1   India  New Delhi  1303171035

# %%
df['Country']
# Out:
# 0    Belgium
# 1      India
# 2     Brazil
# Name: Country, dtype: object

# %% [markdown]
# #### 2.3.1 Selecting by position

# %%
df.iloc[2]
# Out:
# Country          Brazil
# Capital        Brasília
# Population    207847528
# Name: 2, dtype: object

# %% [markdown]
#  iloc[row position,column position]

# %%
df.iloc[2,1]
# Out:
# 'Brasília'

# %%
df.iloc[2,2]
# Out:
# 207847528

# %%
# To get all rows of particular column
df.iloc[:,1]
# Out:
# 0     Brussels
# 1    New Delhi
# 2     Brasília
# Name: Capital, dtype: object

# %%
# To get all columns of particular row
df.iloc[1,:]
# Out:
# Country            India
# Capital        New Delhi
# Population    1303171035
# Name: 1, dtype: object

# %% [markdown]
# #### 2.3.2 Selecting by label/index

# %%
df.loc[1]
# Out:
# Country            India
# Capital        New Delhi
# Population    1303171035
# Name: 1, dtype: object

# %%
df.loc[2]
# Out:
# Country          Brazil
# Capital        Brasília
# Population    207847528
# Name: 2, dtype: object

# %% [markdown]
# #### 2.3.3 Setting values

# %%
s
# Out:
# a    1
# b    2
# c    3
# d    4
# dtype: int64

# %%
s['b'] =4

# %%
s
# Out:
# a    1
# b    4
# c    3
# d    4
# dtype: int64

# %% [markdown]
# ### 2.4 Important functions

# %% [markdown]
# #### 2.4.1 Dropping data

# %%
s.drop(['a'])
# Out:
# b    4
# c    3
# d    4
# dtype: int64

# %%
df.drop('Country',axis =1)
# Out:
#      Capital  Population
# 0   Brussels    11190846
# 1  New Delhi  1303171035
# 2   Brasília   207847528

# %%
df.drop(1,axis =0)
# Out:
#    Country   Capital  Population
# 0  Belgium  Brussels    11190846
# 2   Brazil  Brasília   207847528

# %%
# NOTE: we haven't made any changes to the dataframe itself
df
# Out:
#    Country    Capital  Population
# 0  Belgium   Brussels    11190846
# 1    India  New Delhi  1303171035
# 2   Brazil   Brasília   207847528

# %% [markdown]
# #### 2.4.2 Deleting (Dangerous!!!)

# %%
s
# Out:
# a    1
# b    4
# c    3
# d    4
# dtype: int64

# %%
del s['a']

# %%
# See now its gone !!!!!
s
# Out:
# b    4
# c    3
# d    4
# dtype: int64

# %%
s = pd.Series([1,2,3,4],index=['a','b','c','d'])

# %% [markdown]
# #### 2.4.3 Sorting

# %%
s.sort_index()
# Out:
# a    1
# b    2
# c    3
# d    4
# dtype: int64

# %%
df.sort_index()
# Out:
#    Country    Capital  Population
# 0  Belgium   Brussels    11190846
# 1    India  New Delhi  1303171035
# 2   Brazil   Brasília   207847528

# %%
df.sort_values(by =['Population'])
# Out:
#    Country    Capital  Population
# 0  Belgium   Brussels    11190846
# 2   Brazil   Brasília   207847528
# 1    India  New Delhi  1303171035

# %% [markdown]
# #### 2.4.4 Basic Information

# %%
df.shape
# Out:
# (3, 3)

# %%
df.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
df.columns
# Out:
# Index(['Country', 'Capital', 'Population'], dtype='object')

# %%
list(df)
# Out:
# ['Country', 'Capital', 'Population']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Country     3 non-null      object
#  1   Capital     3 non-null      object
#  2   Population  3 non-null      int64
# dtypes: int64(1), object(2)
# memory usage: 200.0+ bytes

# %%
df.count()
# Out:
# Country       3
# Capital       3
# Population    3
# dtype: int64

# %% [markdown]
# #### 2.4.5 Mathematical ínformation

# %%
df.sum()
# Out:
# Country              BelgiumIndiaBrazil
# Capital       BrusselsNew DelhiBrasília
# Population                   1522209409
# dtype: object

# %%
df.cumsum() ## Cumulative sum
# Out:
#               Country                    Capital  Population
# 0             Belgium                   Brussels    11190846
# 1        BelgiumIndia          BrusselsNew Delhi  1314361881
# 2  BelgiumIndiaBrazil  BrusselsNew DelhiBrasília  1522209409

# %%
df.min()
# Out:
# Country        Belgium
# Capital       Brasília
# Population    11190846
# dtype: object

# %%
df.max()
# Out:
# Country            India
# Capital        New Delhi
# Population    1303171035
# dtype: object

# %%
df.mean()
# Out:
# Population    5.074031e+08
# dtype: float64

# %%
df.describe()
# Out:
#          Population
# count  3.000000e+00
# mean   5.074031e+08
# std    6.961346e+08
# min    1.119085e+07
# 25%    1.095192e+08
# 50%    2.078475e+08
# 75%    7.555093e+08
# max    1.303171e+09

# %% [markdown]
# #### 2.4.6 Applying functions using lambda

# %%
f = lambda x: x**3

# %%
s.apply(f)
# Out:
# a     1
# b     8
# c    27
# d    64
# dtype: int64

# %%
df['Population'].apply(f)
# Out:
# 0          1401485981488991615736
# 1    2213116395641812800458467875
# 2       8979136857202904257341952
# Name: Population, dtype: object

# %% [markdown]
# ### 2.5 I/O Importing and Exporting Data

# %% [markdown]
# #### 2.5.1 CSV files

# %% [markdown]
# Comma seperated files are the most common file types as they represent excel

# %% [markdown]
# ![csv.jfif](attachment:csv.jfif)

# %% [markdown]
# Lets load the most commonly used "Boston Housing Data set"

# %%
df_b = pd.read_csv('C:\\Users\\venka\\Desktop\\TAMachineLearning\\Workshops\\Files\\housing.csv')

# %%
df_b
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio       b  lstat  medv
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# ...

# %%
df_b.describe()
# Out:
#              crim          zn       indus        chas         nox          rm  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               age         dis         rad         tax     ptratio           b  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
df_b.values # Converting to Numpy arrays
# Out:
# array([[6.3200e-03, 1.8000e+01, 2.3100e+00, ..., 3.9690e+02, 4.9800e+00,
#         2.4000e+01],
#        [2.7310e-02, 0.0000e+00, 7.0700e+00, ..., 3.9690e+02, 9.1400e+00,
#         2.1600e+01],
#        [2.7290e-02, 0.0000e+00, 7.0700e+00, ..., 3.9283e+02, 4.0300e+00,
#         3.4700e+01],
#        ...,
#        [6.0760e-02, 0.0000e+00, 1.1930e+01, ..., 3.9690e+02, 5.6400e+00,
#         2.3900e+01],
#        [1.0959e-01, 0.0000e+00, 1.1930e+01, ..., 3.9345e+02, 6.4800e+00,
#         2.2000e+01],
#        [4.7410e-02, 0.0000e+00, 1.1930e+01, ..., 3.9690e+02, 7.8800e+00,
#         1.1900e+01]])

# %%
df_b['crim'].values # Converting to Numpy arrays
# Out:
# array([6.32000e-03, 2.73100e-02, 2.72900e-02, 3.23700e-02, 6.90500e-02,
#        2.98500e-02, 8.82900e-02, 1.44550e-01, 2.11240e-01, 1.70040e-01,
#        2.24890e-01, 1.17470e-01, 9.37800e-02, 6.29760e-01, 6.37960e-01,
#        6.27390e-01, 1.05393e+00, 7.84200e-01, 8.02710e-01, 7.25800e-01,
#        1.25179e+00, 8.52040e-01, 1.23247e+00, 9.88430e-01, 7.50260e-01,
#        8.40540e-01, 6.71910e-01, 9.55770e-01, 7.72990e-01, 1.00245e+00,
#        1.13081e+00, 1.35472e+00, 1.38799e+00, 1.15172e+00, 1.61282e+00,
#        6.41700e-02, 9.74400e-02, 8.01400e-02, 1.75050e-01, 2.76300e-02,
#        3.35900e-02, 1.27440e-01, 1.41500e-01, 1.59360e-01, 1.22690e-01,
#        1.71420e-01, 1.88360e-01, 2.29270e-01, 2.53870e-01, 2.19770e-01,
#        8.87300e-02, 4.33700e-02, 5.36000e-02, 4.98100e-02, 1.36000e-02,
#        1.31100e-02, 2.05500e-02, 1.43200e-02, 1.54450e-01, 1.03280e-01,
#        1.49320e-01, 1.71710e-01, 1.10270e-01, 1.26500e-01, 1.95100e-02,
# ...

# %% [markdown]
# ##### Pls mail to venkatramnank@pesu.pes.edu for doubts and if you encounter any problems regarding this notebook!!
